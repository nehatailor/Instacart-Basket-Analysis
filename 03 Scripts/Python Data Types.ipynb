# %%
x = 50

# %%
y = 50

# %%
x + y
# Out:
# 100

# %%
x = 100

# %%
y = 0

# %%
x - y
# Out:
# 100

# %%
x = 100

# %%
y = 0

# %%
x + y
# Out:
# 100

# %%
x = 2.5

# %%
y = 2.5

# %%
x / y
# Out:
# 1.0

# %%
x = 3.689

# %%
y = 2.635

# %%
x / y
# Out:
# 1.4000000000000001

# %%
a = 'Neha'

# %%
b = 'Tailor'

# %%
a + b
# Out:
# 'NehaTailor'

# %%
a = 'Today'

# %%
b = 'is'

# %%
c = 'the'

# %%
d = 'day.'

# %%
a + b + c + d
# Out:
# 'Todayistheday.'

# %%
a = 'Life'

# %%
b = 'is'

# %%
c = 'beautiful.'

# %%
a + b + c
# Out:
# 'Lifeisbeautiful.'

# %%
n = 'happy'

# %%
n * 100
# Out:
# '...'

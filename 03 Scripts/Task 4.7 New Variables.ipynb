# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\nehat\OneDrive\Desktop\CF DA Immersion\Achievement 4\Instacart Basket Analysis 09'

# %%
# import dataset

df_merge_datasets = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# create a subset

df_sample  = df_merge_datasets[:1000000]

# %%
df_sample
# Out:
#         Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  1   2398795        1    prior             2          3
# 2                  2    473747        1    prior             3          3
# 3                  3   2254736        1    prior             4          4
# 4                  4    431534        1    prior             5          4
# ...              ...       ...      ...      ...           ...        ...
# 999995       2731921   2836489   164627    prior            14          0
# 999996       2731962   1843600   164632    prior             5          1
# 999997       2731966    733106   164632    prior             9          2
# 999998       2731974   1650124   164632    prior            17          6
# 999999       2731979   3378258   164632    prior            22          6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
def price_label(row):
    
    if row['prices'] <=5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <=15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else: return 'Not enough data'

# %%
# Apply the function

df_sample['price_range'] = df_sample.apply(price_label, axis=1)
# Out:
# <ipython-input-16-52f4981a51f7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['price_range'] = df_sample.apply(price_label, axis=1)

# %%
df_sample['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df_sample['prices'].max()
# Out:
# 14.8

# %%
df_sample.loc[df_sample['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\nehat\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_sample.loc[(df_sample['prices'] <= 15) & (df_sample['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\nehat\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_sample.loc[df_sample['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\nehat\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_sample['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
df_merge_datasets.loc[df_merge_datasets['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_merge_datasets.loc[(df_merge_datasets['prices'] <= 15) & (df_merge_datasets['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_merge_datasets.loc[df_merge_datasets['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_merge_datasets['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %%
df_merge_datasets
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    1   2398795        1    prior             2          3
# 2                    2    473747        1    prior             3          3
# 3                    3   2254736        1    prior             4          4
# 4                    4    431534        1    prior             5          4
# ...                ...       ...      ...      ...           ...        ...
# 32434207       3360493   1320836   202557    prior            17          2
# 32434208       3360494     31526   202557    prior            18          5
# 32434209       3376038    758936   203436    prior             1          2
# 32434210       3376039   2745165   203436    prior             2          3
# 32434211       3408036   3093936   205420    prior             1          4
#
# ...

# %%
df_merge_datasets.rename(columns = {'order_dow' : 'orders_day_of_the_week'}, inplace = True)

# %%
df_merge_datasets['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_the_week, dtype: int64

# %%
result = []

for value in df_merge_datasets["orders_day_of_the_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_merge_datasets['busiest_day'] = result

# %%
df_merge_datasets['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## TASK 4.7

# %%
# rename column

df_merge_datasets.rename(columns = {'busiest_day' : 'busiest_days'}, inplace = True)

# %%
# 2 slowest days

result = []

for value in df_merge_datasets["orders_day_of_the_week"]:
  if value == 0 & 1:
    result.append("Busiest days")
  elif value == 3 & 4:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
df_merge_datasets['busiest_days'] = result

# %%
df_merge_datasets['busiest_days'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-a01fadbb1c79> in <module>
# ----> 1 df_merge_datasets["busiest_days"].value_counts(dropna = False)
#
# TypeError: value_counts() got an unexpected keyword argument 'dropna'

# %%
# busiest periods

df_merge_datasets['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
#create new column for busiest period

result = []

for value in df_merge_datasets["order_hour_of_day"]:
    if value == 10:
        result.append("Most Orders")
    elif value == 19 & 20:
        result.append("Average Orders")
    elif value == 3:
        result.append("Fewest Orders")

# %%
result
# Out:
# ['Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
# ...

# %%
 df_merge_datasets['busiest_period_of_day'] = result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-6fe227c9e08b> in <module>
# ----> 1 df_merge_datasets['busiest_period_of_day'] = result
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# ...

# %%
df_merge_datasets['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
df_merge_datasets['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'busiest_period_of_day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Export file to pickle

df_merge_datasets.to.pickle(os.path.join(path, '02 Data', 'Prepared Data', 'new_variables.pkl'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-57b5f8b2d4d1> in <module>
#       1 # Export file to pickle
#       2
# ----> 3 df_merge_datasets.to.pickle(os.path.join(path, '02 Data', 'Prepared Data', 'new_variables.pkl'))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to'

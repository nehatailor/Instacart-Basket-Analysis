# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
df_prods = pd.read_csv(r'C:\Users\nehat\OneDrive\Desktop\CF DA Immersion\Achievement 4\Instacart Basket Analysis 09\02 Data\Prepared Data\products_checked.csv', index_col = False)

# %%
path  = r'C:\Users\nehat\OneDrive\Desktop\CF DA Immersion\Achievement 4\Instacart Basket Analysis 09'

# %%
# Import orders products combined

df_orders_products_combined = pd.read_pickle(r'C:\Users\nehat\OneDrive\Desktop\CF DA Immersion\Achievement 4\Instacart Basket Analysis 09\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
C:#4 Check imported dataframe

df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
#5 Merge orders_products_combined data set with products dataset

df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           0   2539329        1    prior             1          2
# 2           0   2539329        1    prior             1          2
# 3           0   2539329        1    prior             1          2
# 4           0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                1.111484         196                  1
# 1                  8                1.111484       14084                  2
# 2                  8                1.111484       12427                  3
# 3                  8                1.111484       26088                  4
# 4                  8                1.111484       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
df_prods.shape
# Out:
# (49693, 6)

# %%
# merge the 2 datasets

df_merge_datasets = df_orders_products_combined.merge(df_prods, on = 'product_id')

# %%
df_merge_datasets
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    1   2398795        1    prior             2          3
# 2                    2    473747        1    prior             3          3
# 3                    3   2254736        1    prior             4          4
# 4                    4    431534        1    prior             5          4
# ...                ...       ...      ...      ...           ...        ...
# 32434207       3360493   1320836   202557    prior            17          2
# 32434208       3360494     31526   202557    prior            18          5
# 32434209       3376038    758936   203436    prior             1          2
# 32434210       3376039   2745165   203436    prior             2          3
# 32434211       3408036   3093936   205420    prior             1          4
#
# ...

# %%
#7 export in csv format

df_merge_datasets.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl' ))
